# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
import sklearn.metrics as met

# %%
df = pd.read_csv('breast_cancer.csv', header = None)

# %%
df.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# 2  0.3613  0.08758
# 3  0.6638  0.17300
# 4  0.2364  0.07678
#
# [5 rows x 32 columns]

# %%
headers = pd.read_csv('field_names.txt', sep="\n", header = None)

# %%
#type(headers)

# %%
#headers.head()

# %%
titles = headers.values.tolist()

# %%
titles
# Out:
# [['ID'],
#  ['diagnosis'],
#  ['radius_mean'],
#  ['radius_sd_error'],
#  ['radius_worst'],
#  ['texture_mean'],
#  ['texture_sd_error'],
#  ['texture_worst'],
#  ['perimeter_mean'],
#  ['perimeter_sd_error'],
#  ['perimeter_worst'],
#  ['area_mean'],
#  ['area_sd_error'],
#  ['area_worst'],
#  ['smoothness_mean'],
#  ['smoothness_sd_error'],
#  ['smoothness_worst'],
#  ['compactness_mean'],
#  ['compactness_sd_error'],
#  ['compactness_worst'],
#  ['concavity_mean'],
#  ['concavity_sd_error'],
#  ['concavity_worst'],
#  ['concave_points_mean'],
#  ['concave_points_sd_error'],
#  ['concave_points_worst'],
#  ['symmetry_mean'],
#  ['symmetry_sd_error'],
#  ['symmetry_worst'],
#  ['fractal_dimension_mean'],
#  ['fractal_dimension_sd_error'],
#  ['fractal_dimension_worst']]

# %%
len(titles)
# Out:
# 32

# %%
len(df.columns)
# Out:
# 32

# %%
titles = str(titles).replace("[","").replace("]","").replace(" ","").replace("'","")

# %%
titles
# Out:
# 'ID,diagnosis,radius_mean,radius_sd_error,radius_worst,texture_mean,texture_sd_error,texture_worst,perimeter_mean,perimeter_sd_error,perimeter_worst,area_mean,area_sd_error,area_worst,smoothness_mean,smoothness_sd_error,smoothness_worst,compactness_mean,compactness_sd_error,compactness_worst,concavity_mean,concavity_sd_error,concavity_worst,concave_points_mean,concave_points_sd_error,concave_points_worst,symmetry_mean,symmetry_sd_error,symmetry_worst,fractal_dimension_mean,fractal_dimension_sd_error,fractal_dimension_worst'

# %%
titles = titles.split(',')

# %%
titles
# Out:
# ['ID',
#  'diagnosis',
#  'radius_mean',
#  'radius_sd_error',
#  'radius_worst',
#  'texture_mean',
#  'texture_sd_error',
#  'texture_worst',
#  'perimeter_mean',
#  'perimeter_sd_error',
#  'perimeter_worst',
#  'area_mean',
#  'area_sd_error',
#  'area_worst',
#  'smoothness_mean',
#  'smoothness_sd_error',
#  'smoothness_worst',
#  'compactness_mean',
#  'compactness_sd_error',
#  'compactness_worst',
#  'concavity_mean',
#  'concavity_sd_error',
#  'concavity_worst',
#  'concave_points_mean',
#  'concave_points_sd_error',
#  'concave_points_worst',
#  'symmetry_mean',
#  'symmetry_sd_error',
#  'symmetry_worst',
#  'fractal_dimension_mean',
#  'fractal_dimension_sd_error',
#  'fractal_dimension_worst']

# %%
df = pd.read_csv('breast_cancer.csv', header=None, names=titles)

# %%
df.head()
# Out:
#          ID diagnosis  radius_mean  radius_sd_error  radius_worst  \
# 0    842302         M        17.99            10.38        122.80
# 1    842517         M        20.57            17.77        132.90
# 2  84300903         M        19.69            21.25        130.00
# 3  84348301         M        11.42            20.38         77.58
# 4  84358402         M        20.29            14.34        135.10
#
#    texture_mean  texture_sd_error  texture_worst  perimeter_mean  \
# 0        1001.0           0.11840        0.27760          0.3001
# 1        1326.0           0.08474        0.07864          0.0869
# 2        1203.0           0.10960        0.15990          0.1974
# 3         386.1           0.14250        0.28390          0.2414
# 4        1297.0           0.10030        0.13280          0.1980
#
#    perimeter_sd_error  ...  concavity_worst  concave_points_mean  \
# 0             0.14710  ...            25.38                17.33
# 1             0.07017  ...            24.99                23.41
# 2             0.12790  ...            23.57                25.53
# 3             0.10520  ...            14.91                26.50
# 4             0.10430  ...            22.54                16.67
#
#    concave_points_sd_error  concave_points_worst  symmetry_mean  \
# 0                   184.60                2019.0         0.1622
# 1                   158.80                1956.0         0.1238
# 2                   152.50                1709.0         0.1444
# 3                    98.87                 567.7         0.2098
# 4                   152.20                1575.0         0.1374
#
#    symmetry_sd_error  symmetry_worst  fractal_dimension_mean  \
# 0             0.6656          0.7119                  0.2654
# 1             0.1866          0.2416                  0.1860
# 2             0.4245          0.4504                  0.2430
# 3             0.8663          0.6869                  0.2575
# 4             0.2050          0.4000                  0.1625
#
#    fractal_dimension_sd_error  fractal_dimension_worst
# 0                      0.4601                  0.11890
# 1                      0.2750                  0.08902
# 2                      0.3613                  0.08758
# 3                      0.6638                  0.17300
# 4                      0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.corr()
# Out:
#                                   ID  radius_mean  radius_sd_error  \
# ID                          1.000000     0.074626         0.099770
# radius_mean                 0.074626     1.000000         0.323782
# radius_sd_error             0.099770     0.323782         1.000000
# radius_worst                0.073159     0.997855         0.329533
# texture_mean                0.096893     0.987357         0.321086
# texture_sd_error           -0.012968     0.170581        -0.023389
# texture_worst               0.000096     0.506124         0.236702
# perimeter_mean              0.050080     0.676764         0.302418
# perimeter_sd_error          0.044158     0.822529         0.293464
# perimeter_worst            -0.022114     0.147741         0.071401
# area_mean                  -0.052511    -0.311631        -0.076437
# area_sd_error               0.143048     0.679090         0.275869
# area_worst                 -0.007526    -0.097317         0.386358
# smoothness_mean             0.137331     0.674172         0.281673
# smoothness_sd_error         0.177742     0.735864         0.259845
# smoothness_worst            0.096781    -0.222600         0.006614
# compactness_mean            0.033961     0.206000         0.191975
# compactness_sd_error        0.055239     0.194204         0.143293
# compactness_worst           0.078768     0.376169         0.163851
# concavity_mean             -0.017306    -0.104321         0.009127
# concavity_sd_error          0.025725    -0.042641         0.054458
# concavity_worst             0.082405     0.969539         0.352573
# concave_points_mean         0.064720     0.297008         0.912045
# concave_points_sd_error     0.079986     0.965137         0.358040
# concave_points_worst        0.107187     0.941082         0.343546
# symmetry_mean               0.010338     0.119616         0.077503
# symmetry_sd_error          -0.002968     0.413463         0.277830
# symmetry_worst              0.023203     0.526911         0.301025
# fractal_dimension_mean      0.035174     0.744214         0.295316
# fractal_dimension_sd_error -0.044224     0.163953         0.105008
# fractal_dimension_worst    -0.029866     0.007066         0.119205
#
#                             radius_worst  texture_mean  texture_sd_error  \
# ID                              0.073159      0.096893         -0.012968
# radius_mean                     0.997855      0.987357          0.170581
# radius_sd_error                 0.329533      0.321086         -0.023389
# radius_worst                    1.000000      0.986507          0.207278
# texture_mean                    0.986507      1.000000          0.177028
# texture_sd_error                0.207278      0.177028          1.000000
# texture_worst                   0.556936      0.498502          0.659123
# perimeter_mean                  0.716136      0.685983          0.521984
# perimeter_sd_error              0.850977      0.823269          0.553695
# perimeter_worst                 0.183027      0.151293          0.557775
# area_mean                      -0.261477     -0.283110          0.584792
# area_sd_error                   0.691765      0.732562          0.301467
# area_worst                     -0.086761     -0.066280          0.068406
# smoothness_mean                 0.693135      0.726628          0.296092
# smoothness_sd_error             0.744983      0.800086          0.246552
# smoothness_worst               -0.202694     -0.166777          0.332375
# compactness_mean                0.250744      0.212583          0.318943
# compactness_sd_error            0.228082      0.207660          0.248396
# compactness_worst               0.407217      0.372320          0.380676
# concavity_mean                 -0.081629     -0.072497          0.200774
# concavity_sd_error             -0.005523     -0.019887          0.283607
# concavity_worst                 0.969476      0.962746          0.213120
# concave_points_mean             0.303038      0.287489          0.036072
# concave_points_sd_error         0.970387      0.959120          0.238853
# concave_points_worst            0.941550      0.959213          0.206718
# symmetry_mean                   0.150549      0.123523          0.805324
# symmetry_sd_error               0.455774      0.390410          0.472468
# symmetry_worst                  0.563879      0.512606          0.434926
# fractal_dimension_mean          0.771241      0.722017          0.503053
# fractal_dimension_sd_error      0.189115      0.143570          0.394309
# fractal_dimension_worst         0.051019      0.003738          0.499316
#
#                             texture_worst  perimeter_mean  perimeter_sd_error  \
# ID                               0.000096        0.050080            0.044158
# radius_mean                      0.506124        0.676764            0.822529
# radius_sd_error                  0.236702        0.302418            0.293464
# radius_worst                     0.556936        0.716136            0.850977
# texture_mean                     0.498502        0.685983            0.823269
# texture_sd_error                 0.659123        0.521984            0.553695
# texture_worst                    1.000000        0.883121            0.831135
# perimeter_mean                   0.883121        1.000000            0.921391
# perimeter_sd_error               0.831135        0.921391            1.000000
# perimeter_worst                  0.602641        0.500667            0.462497
# area_mean                        0.565369        0.336783            0.166917
# area_sd_error                    0.497473        0.631925            0.698050
# area_worst                       0.046205        0.076218            0.021480
# smoothness_mean                  0.548905        0.660391            0.710650
# smoothness_sd_error              0.455653        0.617427            0.690299
# smoothness_worst                 0.135299        0.098564            0.027653
# compactness_mean                 0.738722        0.670279            0.490424
# compactness_sd_error             0.570517        0.691270            0.439167
# compactness_worst                0.642262        0.683260            0.615634
# concavity_mean                   0.229977        0.178009            0.095351
# concavity_sd_error               0.507318        0.449301            0.257584
# concavity_worst                  0.535315        0.688236            0.830318
# concave_points_mean              0.248133        0.299879            0.292752
# concave_points_sd_error          0.590210        0.729565            0.855923
# concave_points_worst             0.509604        0.675987            0.809630
# symmetry_mean                    0.565541        0.448822            0.452753
# symmetry_sd_error                0.865809        0.754968            0.667454
# symmetry_worst                   0.816275        0.884103            0.752399
# fractal_dimension_mean           0.815573        0.861323            0.910155
# fractal_dimension_sd_error       0.510223        0.409464            0.375744
# fractal_dimension_worst          0.687382        0.514930            0.368661
#
#                             perimeter_worst  ...  concavity_worst  \
# ID                                -0.022114  ...         0.082405
# radius_mean                        0.147741  ...         0.969539
# radius_sd_error                    0.071401  ...         0.352573
# radius_worst                       0.183027  ...         0.969476
# texture_mean                       0.151293  ...         0.962746
# texture_sd_error                   0.557775  ...         0.213120
# texture_worst                      0.602641  ...         0.535315
# perimeter_mean                     0.500667  ...         0.688236
# perimeter_sd_error                 0.462497  ...         0.830318
# perimeter_worst                    1.000000  ...         0.185728
# area_mean                          0.479921  ...        -0.253691
# area_sd_error                      0.303379  ...         0.715065
# area_worst                         0.128053  ...        -0.111690
# smoothness_mean                    0.313893  ...         0.697201
# smoothness_sd_error                0.223970  ...         0.757373
# smoothness_worst                   0.187321  ...        -0.230691
# compactness_mean                   0.421659  ...         0.204607
# compactness_sd_error               0.342627  ...         0.186904
# compactness_worst                  0.393298  ...         0.358127
# concavity_mean                     0.449137  ...        -0.128121
# concavity_sd_error                 0.331786  ...        -0.037488
# concavity_worst                    0.185728  ...         1.000000
# concave_points_mean                0.090651  ...         0.359921
# concave_points_sd_error            0.219169  ...         0.993708
# concave_points_worst               0.177193  ...         0.984015
# symmetry_mean                      0.426675  ...         0.216574
# symmetry_sd_error                  0.473200  ...         0.475820
# symmetry_worst                     0.433721  ...         0.573975
# fractal_dimension_mean             0.430297  ...         0.787424
# fractal_dimension_sd_error         0.699826  ...         0.243529
# fractal_dimension_worst            0.438413  ...         0.093492
#
#                             concave_points_mean  concave_points_sd_error  \
# ID                                     0.064720                 0.079986
# radius_mean                            0.297008                 0.965137
# radius_sd_error                        0.912045                 0.358040
# radius_worst                           0.303038                 0.970387
# texture_mean                           0.287489                 0.959120
# texture_sd_error                       0.036072                 0.238853
# texture_worst                          0.248133                 0.590210
# perimeter_mean                         0.299879                 0.729565
# perimeter_sd_error                     0.292752                 0.855923
# perimeter_worst                        0.090651                 0.219169
# area_mean                             -0.051269                -0.205151
# area_sd_error                          0.194799                 0.719684
# area_worst                             0.409003                -0.102242
# smoothness_mean                        0.200371                 0.721031
# smoothness_sd_error                    0.196497                 0.761213
# smoothness_worst                      -0.074743                -0.217304
# compactness_mean                       0.143003                 0.260516
# compactness_sd_error                   0.100241                 0.226680
# compactness_worst                      0.086741                 0.394999
# concavity_mean                        -0.077473                -0.103753
# concavity_sd_error                    -0.003195                -0.001000
# concavity_worst                        0.359921                 0.993708
# concave_points_mean                    1.000000                 0.365098
# concave_points_sd_error                0.365098                 1.000000
# concave_points_worst                   0.345842                 0.977578
# symmetry_mean                          0.225429                 0.236775
# symmetry_sd_error                      0.360832                 0.529408
# symmetry_worst                         0.368366                 0.618344
# fractal_dimension_mean                 0.359755                 0.816322
# fractal_dimension_sd_error             0.233027                 0.269493
# fractal_dimension_worst                0.219122                 0.138957
#
#                             concave_points_worst  symmetry_mean  \
# ID                                      0.107187       0.010338
# radius_mean                             0.941082       0.119616
# radius_sd_error                         0.343546       0.077503
# radius_worst                            0.941550       0.150549
# texture_mean                            0.959213       0.123523
# texture_sd_error                        0.206718       0.805324
# texture_worst                           0.509604       0.565541
# perimeter_mean                          0.675987       0.448822
# perimeter_sd_error                      0.809630       0.452753
# perimeter_worst                         0.177193       0.426675
# area_mean                              -0.231854       0.504942
# area_sd_error                           0.751548       0.141919
# area_worst                             -0.083195      -0.073658
# smoothness_mean                         0.730713       0.130054
# smoothness_sd_error                     0.811408       0.125389
# smoothness_worst                       -0.182195       0.314457
# compactness_mean                        0.199371       0.227394
# compactness_sd_error                    0.188353       0.168481
# compactness_worst                       0.342271       0.215351
# concavity_mean                         -0.110343      -0.012662
# concavity_sd_error                     -0.022736       0.170568
# concavity_worst                         0.984015       0.216574
# concave_points_mean                     0.345842       0.225429
# concave_points_sd_error                 0.977578       0.236775
# concave_points_worst                    1.000000       0.209145
# symmetry_mean                           0.209145       1.000000
# symmetry_sd_error                       0.438296       0.568187
# symmetry_worst                          0.543331       0.518523
# fractal_dimension_mean                  0.747419       0.547691
# fractal_dimension_sd_error              0.209146       0.493838
# fractal_dimension_worst                 0.079647       0.617624
#
#                             symmetry_sd_error  symmetry_worst  \
# ID                                  -0.002968        0.023203
# radius_mean                          0.413463        0.526911
# radius_sd_error                      0.277830        0.301025
# radius_worst                         0.455774        0.563879
# texture_mean                         0.390410        0.512606
# texture_sd_error                     0.472468        0.434926
# texture_worst                        0.865809        0.816275
# perimeter_mean                       0.754968        0.884103
# perimeter_sd_error                   0.667454        0.752399
# perimeter_worst                      0.473200        0.433721
# area_mean                            0.458798        0.346234
# area_sd_error                        0.287103        0.380585
# area_worst                          -0.092439       -0.068956
# smoothness_mean                      0.341919        0.418899
# smoothness_sd_error                  0.283257        0.385100
# smoothness_worst                    -0.055558       -0.058298
# compactness_mean                     0.678780        0.639147
# compactness_sd_error                 0.484858        0.662564
# compactness_worst                    0.452888        0.549592
# concavity_mean                       0.060255        0.037119
# concavity_sd_error                   0.390159        0.379975
# concavity_worst                      0.475820        0.573975
# concave_points_mean                  0.360832        0.368366
# concave_points_sd_error              0.529408        0.618344
# concave_points_worst                 0.438296        0.543331
# symmetry_mean                        0.568187        0.518523
# symmetry_sd_error                    1.000000        0.892261
# symmetry_worst                       0.892261        1.000000
# fractal_dimension_mean               0.801080        0.855434
# fractal_dimension_sd_error           0.614441        0.532520
# fractal_dimension_worst              0.810455        0.686511
#
#                             fractal_dimension_mean  \
# ID                                        0.035174
# radius_mean                               0.744214
# radius_sd_error                           0.295316
# radius_worst                              0.771241
# texture_mean                              0.722017
# texture_sd_error                          0.503053
# texture_worst                             0.815573
# perimeter_mean                            0.861323
# perimeter_sd_error                        0.910155
# perimeter_worst                           0.430297
# area_mean                                 0.175325
# area_sd_error                             0.531062
# area_worst                               -0.119638
# smoothness_mean                           0.554897
# smoothness_sd_error                       0.538166
# smoothness_worst                         -0.102007
# compactness_mean                          0.483208
# compactness_sd_error                      0.440472
# compactness_worst                         0.602450
# concavity_mean                           -0.030413
# concavity_sd_error                        0.215204
# concavity_worst                           0.787424
# concave_points_mean                       0.359755
# concave_points_sd_error                   0.816322
# concave_points_worst                      0.747419
# symmetry_mean                             0.547691
# symmetry_sd_error                         0.801080
# symmetry_worst                            0.855434
# fractal_dimension_mean                    1.000000
# fractal_dimension_sd_error                0.502528
# fractal_dimension_worst                   0.511114
#
#                             fractal_dimension_sd_error  \
# ID                                           -0.044224
# radius_mean                                   0.163953
# radius_sd_error                               0.105008
# radius_worst                                  0.189115
# texture_mean                                  0.143570
# texture_sd_error                              0.394309
# texture_worst                                 0.510223
# perimeter_mean                                0.409464
# perimeter_sd_error                            0.375744
# perimeter_worst                               0.699826
# area_mean                                     0.334019
# area_sd_error                                 0.094543
# area_worst                                   -0.128215
# smoothness_mean                               0.109930
# smoothness_sd_error                           0.074126
# smoothness_worst                             -0.107342
# compactness_mean                              0.277878
# compactness_sd_error                          0.197788
# compactness_worst                             0.143116
# concavity_mean                                0.389402
# concavity_sd_error                            0.111094
# concavity_worst                               0.243529
# concave_points_mean                           0.233027
# concave_points_sd_error                       0.269493
# concave_points_worst                          0.209146
# symmetry_mean                                 0.493838
# symmetry_sd_error                             0.614441
# symmetry_worst                                0.532520
# fractal_dimension_mean                        0.502528
# fractal_dimension_sd_error                    1.000000
# fractal_dimension_worst                       0.537848
#
#                             fractal_dimension_worst
# ID                                        -0.029866
# radius_mean                                0.007066
# radius_sd_error                            0.119205
# radius_worst                               0.051019
# texture_mean                               0.003738
# texture_sd_error                           0.499316
# texture_worst                              0.687382
# perimeter_mean                             0.514930
# perimeter_sd_error                         0.368661
# perimeter_worst                            0.438413
# area_mean                                  0.767297
# area_sd_error                              0.049559
# area_worst                                -0.045655
# smoothness_mean                            0.085433
# smoothness_sd_error                        0.017539
# smoothness_worst                           0.101480
# compactness_mean                           0.590973
# compactness_sd_error                       0.439329
# compactness_worst                          0.310655
# concavity_mean                             0.078079
# concavity_sd_error                         0.591328
# concavity_worst                            0.093492
# concave_points_mean                        0.219122
# concave_points_sd_error                    0.138957
# concave_points_worst                       0.079647
# symmetry_mean                              0.617624
# symmetry_sd_error                          0.810455
# symmetry_worst                             0.686511
# fractal_dimension_mean                     0.511114
# fractal_dimension_sd_error                 0.537848
# fractal_dimension_worst                    1.000000
#
# [31 rows x 31 columns]

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,cmap='RdBu_r')

# %%
df1 = df.copy()

# %%
df1 = df1.drop(columns = 'ID')

# %%
df1.diagnosis.unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
df1 = MultiColumnLabelEncoder(columns = ['diagnosis']).fit_transform(df1)

# %%
df1.head()
# Out:
#    diagnosis  radius_mean  radius_sd_error  radius_worst  texture_mean  \
# 0          1        17.99            10.38        122.80        1001.0
# 1          1        20.57            17.77        132.90        1326.0
# 2          1        19.69            21.25        130.00        1203.0
# 3          1        11.42            20.38         77.58         386.1
# 4          1        20.29            14.34        135.10        1297.0
#
#    texture_sd_error  texture_worst  perimeter_mean  perimeter_sd_error  \
# 0           0.11840        0.27760          0.3001             0.14710
# 1           0.08474        0.07864          0.0869             0.07017
# 2           0.10960        0.15990          0.1974             0.12790
# 3           0.14250        0.28390          0.2414             0.10520
# 4           0.10030        0.13280          0.1980             0.10430
#
#    perimeter_worst  ...  concavity_worst  concave_points_mean  \
# 0           0.2419  ...            25.38                17.33
# 1           0.1812  ...            24.99                23.41
# 2           0.2069  ...            23.57                25.53
# 3           0.2597  ...            14.91                26.50
# 4           0.1809  ...            22.54                16.67
#
#    concave_points_sd_error  concave_points_worst  symmetry_mean  \
# 0                   184.60                2019.0         0.1622
# 1                   158.80                1956.0         0.1238
# 2                   152.50                1709.0         0.1444
# 3                    98.87                 567.7         0.2098
# 4                   152.20                1575.0         0.1374
#
#    symmetry_sd_error  symmetry_worst  fractal_dimension_mean  \
# 0             0.6656          0.7119                  0.2654
# 1             0.1866          0.2416                  0.1860
# 2             0.4245          0.4504                  0.2430
# 3             0.8663          0.6869                  0.2575
# 4             0.2050          0.4000                  0.1625
#
#    fractal_dimension_sd_error  fractal_dimension_worst
# 0                      0.4601                  0.11890
# 1                      0.2750                  0.08902
# 2                      0.3613                  0.08758
# 3                      0.6638                  0.17300
# 4                      0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df1.diagnosis.unique()
# Out:
# array([1, 0])

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df1.corr(),annot=True,cmap='RdBu_r')

# %% [markdown]
# # Applying Naive Bayes Model

# %%
X = df1.iloc[:, 1:]

# %%
X.head(1)
# Out:
#    radius_mean  radius_sd_error  radius_worst  texture_mean  texture_sd_error  \
# 0        17.99            10.38         122.8        1001.0            0.1184
#
#    texture_worst  perimeter_mean  perimeter_sd_error  perimeter_worst  \
# 0         0.2776          0.3001              0.1471           0.2419
#
#    area_mean  ...  concavity_worst  concave_points_mean  \
# 0    0.07871  ...            25.38                17.33
#
#    concave_points_sd_error  concave_points_worst  symmetry_mean  \
# 0                    184.6                2019.0         0.1622
#
#    symmetry_sd_error  symmetry_worst  fractal_dimension_mean  \
# 0             0.6656          0.7119                  0.2654
#
#    fractal_dimension_sd_error  fractal_dimension_worst
# 0                      0.4601                   0.1189
#
# [1 rows x 30 columns]

# %%
Y = df1.iloc[:, 0]

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state =0)

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
classifier = GaussianNB()

# %%
classifier.fit(X_train, Y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
Y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(Y_test, Y_pred)

# %%
cm
# Out:
# array([[64,  3],
#        [ 4, 43]])

# %%
met.accuracy_score(Y_test, Y_pred)
# Out:
# 0.9385964912280702
